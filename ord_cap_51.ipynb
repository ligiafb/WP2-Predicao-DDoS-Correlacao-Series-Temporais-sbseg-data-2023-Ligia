# %%
import pandas as pd
import numpy as np
import ordpy
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %%
df = pd.read_csv("cap_51.csv", sep=";")
df
# Out:
#       Unnamed: 0  total_ips_origem  total_ips_destino  total_pacotes  has_bot
# 0              0               108                117           1343        0
# 1              1               145                182           1829        0
# 2              2               183                182           1794        0
# 3              3               159                166           1797        0
# 4              4               176                186           2047        0
# ...          ...               ...                ...            ...      ...
# 6995        6995               161                165           3291        0
# 6996        6996               159                164           3100        0
# 6997        6997               164                165           4231        0
# 6998        6998               170                171           3344        0
# 6999        6999               152                154           3108        0
#
# [7000 rows x 5 columns]

# %% [markdown]
# # Loop para extrair as métricas sem variar o taux

# %%
# Matriz com as métricas
matrix = []
label = []

# Definição do Tau e Dx
taux = 1
dx = 3

# Time set
init = 0
end = 440 #(5%)

for i in range (1, end):
    matrix.append( [ [init, i] ] )

for i in range(0,6561): #972-48+1
    # Vetor para guardar as métricas
    vec = []
    vec.append([init, end])
    # COLUNA TOTAL_IPS_ORIGEM

    # Calculo da Entropia e da Complexidade
    tmp = ordpy.complexity_entropy(df['total_ips_origem'][init:end], dx=dx, taux=taux)
    vec.append(tmp[0])
    vec.append(tmp[1])

     #Calculo da Informação de Fisher Shannon
    tmp = ordpy.fisher_shannon(df['total_ips_origem'][init:end], dx=dx, taux=taux)
    vec.append(tmp[1])

    # Transformação em grafo de transição
    edges = ordpy.ordinal_network(df['total_ips_origem'][init:end], dx=dx, taux=taux)

    # Entropia e complexidade do grafo
    tmp = ordpy.complexity_entropy(edges[2], dx=dx, taux=taux)
    vec.append(tmp[0])
    vec.append(tmp[1])

    # Informação de fisher do grafo
    tmp = ordpy.fisher_shannon(edges[2], dx=dx, taux=taux)
    vec.append(tmp[1])

    # Quantidade de arestas
    tmp = len(edges[1])
    vec.append(tmp)

    # Extração dos índices das autotransições
    j=0
    indices = []
    for array in edges[1]:
        if(array[0] == array[1]):
            indices.append(j)
        j += 1

    # Calculo da probabilidade de autotransição
    prob = 0
    for index in indices:
        tmp = edges[2][index]
        prob += tmp
    vec.append(prob)

    # COLUNA TOTAL_IPS_DESTINO

    # Calculo da Entropia e da Complexidade
    tmp = ordpy.complexity_entropy(df['total_ips_destino'][init:end], dx=dx, taux=taux)
    vec.append(tmp[0])
    vec.append(tmp[1])

    #Calculo da Informação de Fisher Shannon
    tmp = ordpy.fisher_shannon(df['total_ips_destino'][init:end], dx=dx, taux=taux)
    vec.append(tmp[1])

    # Transformação em grafo de transição
    edges = ordpy.ordinal_network(df['total_ips_destino'][init:end], dx=dx, taux=taux)

    # Entropia e complexidade do grafo
    tmp = ordpy.complexity_entropy(edges[2], dx=dx, taux=taux)
    vec.append(tmp[0])
    vec.append(tmp[1])

    # Informação de fisher do grafo
    tmp = ordpy.fisher_shannon(edges[2], dx=dx, taux=taux)
    vec.append(tmp[1])

    # Quantidade de arestas
    tmp = len(edges[1])
    vec.append(tmp)

    # Extração dos índices das autotransições
    j=0
    indices = []
    for array in edges[1]:
        if(array[0] == array[1]):
            indices.append(j)
        j += 1

    # Calculo da probabilidade de autotransição
    prob = 0
    for index in indices:
        tmp = edges[2][index]
        prob += tmp
    vec.append(prob)

    # COLUNA TOTAL_PACOTES

    # Calculo da Entropia e da Complexidade
    tmp = ordpy.complexity_entropy(df['total_pacotes'][init:end], dx=dx, taux=taux)
    vec.append(tmp[0])
    vec.append(tmp[1])

    #Calculo da Informação de Fisher Shannon
    tmp = ordpy.fisher_shannon(df['total_pacotes'][init:end], dx=dx, taux=taux)
    vec.append(tmp[1])

    # Transformação em grafo de transição
    edges = ordpy.ordinal_network(df['total_pacotes'][init:end], dx=dx, taux=taux)

    # Entropia e complexidade do grafo
    tmp = ordpy.complexity_entropy(edges[2], dx=dx, taux=taux)
    vec.append(tmp[0])
    vec.append(tmp[1])

    # Informação de fisher do grafo
    tmp = ordpy.fisher_shannon(edges[2], dx=dx, taux=taux)
    vec.append(tmp[1])

    # Quantidade de arestas
    tmp = len(edges[1])
    vec.append(tmp)

    # Extração dos índices das autotransições
    j=0
    indices = []
    for array in edges[1]:
        if(array[0] == array[1]):
            indices.append(j)
        j += 1

    # Calculo da probabilidade de autotransição
    prob = 0
    for index in indices:
        tmp = edges[2][index]
        prob += tmp
    vec.append(prob)


    # Adiciona as métricas a matriz
    matrix.append(vec)

    # Vetor label
    bot = 0
    for line in df.iloc[init:end].iterrows():
        if(line[1][4] == 1):
            bot = 1
    label.append(bot)
        
     # Loop de tempo
    init = init + 1
    end = end + 1

    
# Cria um dataframe com a matriz
ft = pd.DataFrame(matrix, columns = ['time',
                                     'IPO_entropy', 'IPO_complexity' , 'IPO_fisher_shanon', 'IPO_edge_entropy', 'IPO_edge_complexity', 'IPO_edge_fisher_shannon', 'IPO_number_nodes', 'IPO_self_transition',
                                     'IPD_entropy', 'IPD_complexity' , 'IPD_fisher_shanon', 'IPD_edge_entropy', 'IPD_edge_complexity', 'IPD_edge_fisher_shannon', 'IPD_number_nodes', 'IPD_self_transition',
                                     'TP_entropy', 'TP_complexity' , 'TP_fisher_shanon', 'TP_edge_entropy', 'TP_edge_complexity', 'TP_edge_fisher_shannon', 'TP_number_nodes', 'TP_self_transition'])
ft
ft.to_csv('po_51.csv',sep=';')

# %%
ft
# Out:
#               time  IPO_entropy  IPO_complexity  IPO_fisher_shanon  \
# 0           [0, 1]          NaN             NaN                NaN
# 1           [0, 2]          NaN             NaN                NaN
# 2           [0, 3]          NaN             NaN                NaN
# 3           [0, 4]          NaN             NaN                NaN
# 4           [0, 5]          NaN             NaN                NaN
# ...            ...          ...             ...                ...
# 6995  [6556, 6996]     0.998271        0.001704           0.001622
# 6996  [6557, 6997]     0.998431        0.001546           0.001536
# 6997  [6558, 6998]     0.998431        0.001546           0.001517
# 6998  [6559, 6999]     0.998431        0.001546           0.001517
# 6999  [6560, 7000]     0.998175        0.001795           0.001791
#
#       IPO_edge_entropy  IPO_edge_complexity  IPO_edge_fisher_shannon  \
# 0                  NaN                  NaN                      NaN
# 1                  NaN                  NaN                      NaN
# 2                  NaN                  NaN                      NaN
# 3                  NaN                  NaN                      NaN
# 4                  NaN                  NaN                      NaN
# ...                ...                  ...                      ...
# 6995          0.843353             0.160021                 0.151427
# 6996          0.843353             0.160021                 0.151427
# 6997          0.843353             0.160021                 0.151427
# 6998          0.843353             0.160021                 0.151427
# 6999          0.843353             0.160021                 0.151427
#
#       IPO_number_nodes  IPO_self_transition  IPD_entropy  ...  \
# 0                  NaN                  NaN          NaN  ...
# 1                  NaN                  NaN          NaN  ...
# 2                  NaN                  NaN          NaN  ...
# 3                  NaN                  NaN          NaN  ...
# 4                  NaN                  NaN          NaN  ...
# ...                ...                  ...          ...  ...
# 6995              18.0             0.080092     0.999411  ...
# 6996              18.0             0.080092     0.999446  ...
# 6997              18.0             0.077803     0.999463  ...
# 6998              18.0             0.077803     0.999463  ...
# 6999              18.0             0.077803     0.999429  ...
#
#       IPD_number_nodes  IPD_self_transition  TP_entropy  TP_complexity  \
# 0                  NaN                  NaN         NaN            NaN
# 1                  NaN                  NaN         NaN            NaN
# 2                  NaN                  NaN         NaN            NaN
# 3                  NaN                  NaN         NaN            NaN
# 4                  NaN                  NaN         NaN            NaN
# ...                ...                  ...         ...            ...
# 6995              18.0             0.070938    0.998059       0.001905
# 6996              18.0             0.070938    0.998206       0.001757
# 6997              18.0             0.068650    0.998406       0.001565
# 6998              18.0             0.068650    0.998454       0.001520
# 6999              18.0             0.068650    0.998397       0.001578
#
#       TP_fisher_shanon  TP_edge_entropy  TP_edge_complexity  \
# 0                  NaN              NaN                 NaN
# 1                  NaN              NaN                 NaN
# 2                  NaN              NaN                 NaN
# 3                  NaN              NaN                 NaN
# 4                  NaN              NaN                 NaN
# ...                ...              ...                 ...
# 6995          0.000771         0.882272            0.132674
# 6996          0.000590         0.882272            0.132674
# 6997          0.000479         0.882272            0.132674
# 6998          0.000492         0.882272            0.132674
# 6999          0.000607         0.882272            0.132674
#
#       TP_edge_fisher_shannon  TP_number_nodes  TP_self_transition
# 0                        NaN              NaN                 NaN
# 1                        NaN              NaN                 NaN
# 2                        NaN              NaN                 NaN
# 3                        NaN              NaN                 NaN
# 4                        NaN              NaN                 NaN
# ...                      ...              ...                 ...
# 6995                0.143367             18.0            0.112128
# 6996                0.143367             18.0            0.112128
# 6997                0.143367             18.0            0.109840
# 6998                0.143367             18.0            0.109840
# 6999                0.143367             18.0            0.109840
#
# [7000 rows x 25 columns]

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import confusion_matrix
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

po = pd.read_csv("po_51.csv", sep=";")
early_warning = pd.read_csv("cap_51.csv", sep=";")

colunas = ['total_ips_origem', 'total_ips_destino', 'total_pacotes']

df = po[['IPO_entropy', 'IPO_complexity',
       'IPO_fisher_shanon', 'IPO_edge_entropy', 'IPO_edge_complexity',
       'IPO_edge_fisher_shannon', 'IPO_number_nodes', 'IPO_self_transition',
       'IPD_entropy', 'IPD_complexity', 'IPD_fisher_shanon',
       'IPD_edge_entropy', 'IPD_edge_complexity', 'IPD_edge_fisher_shannon',
       'IPD_number_nodes', 'IPD_self_transition', 'TP_entropy',
       'TP_complexity', 'TP_fisher_shanon', 'TP_edge_entropy',
       'TP_edge_complexity', 'TP_edge_fisher_shannon', 'TP_number_nodes',
       'TP_self_transition']]
label = early_warning['has_bot']

init = 440
train = 2934
end = 5634

x_train = df[init:train]
x_test = df[train:end]
y_real = label[train:end]

clf = OneClassSVM(gamma='auto', kernel='poly', nu=0.1).fit(x_train)
y_test = clf.predict(x_test)
y_test_final = [0 if i == 1 else 1 for i in y_test]
acc = accuracy_score(y_real, y_test_final)
print(acc)
print(confusion_matrix(y_real, y_test_final))
print(classification_report(y_real, y_test_final))
# Out:
# 0.8988888888888888
# [[2424   60]
#  [ 213    3]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      2484
#            1       0.05      0.01      0.02       216
#
#     accuracy                           0.90      2700
#    macro avg       0.48      0.49      0.48      2700
# weighted avg       0.85      0.90      0.87      2700
